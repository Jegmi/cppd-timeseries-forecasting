# %% [markdown]
# # Load 15min Fitbit data and train patient model

# %%
# %cd /hpc/users/jegmij01/jannes_setup/cpp_project
# Out:
# /hpc/users/jegmij01/jannes_setup/cpp_project

# %%
# custom modules
import config
from features import preprocessing as pp
from helpers import io_helpers as io
from helpers import plot_helpers as pics

from matplotlib import pyplot as plt

# %% [markdown]
# # Load data

# %%
# from data.datasets import Dataset_CPP
import pickle
filepath = config.DATA_PATH / 'private/cpp/20240820pkls/min15.pkl'
with open(filepath, 'rb') as f:
    raw_data = pickle.load(f)

# %%
config.fig_path
# Out:
# PosixPath('/sc/arion/work/jegmij01/patchtst/datasets/../pic/data_grids')

# %% [markdown]
# # Create raw_data images

# %%
for p_idx in raw_data.keys():
    
    if len(raw_data[p_idx]) == 0: # or p_idx < 54: 
        print('skip .. no data in raw_data object for p_idx', p_idx)
        continue
    
    dfs = io.get_person_data(raw_data,p_idx)
    arr = io.get_nan_imputed_array(dfs)
        
    if len(arr) < 20:
        print(p_idx, 'too few days', arr.shape)
        continue
    
    ax=pics.arr_to_pcolor_plt(arr)
    ax.set_title(f'Activity patient {p_idx}')

    #break
    #pic.savefig(f'patient_{p_idx}_15min_grid', fig_path=config.fig_path)
    plt.show()
    plt.close()
    break
# Out:
# 100%|██████████| 81/81 [00:00<00:00, 1671.47it/s]
# /hpc/users/jegmij01/jannes_setup/cpp_project/helpers/io_helpers.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(X_imputed).astype(float)

# %% [markdown]
# # Linear baseline for Auto-Regression Task

# %%
from data.datasets import Dataset_CPP
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from models import pytorch_models

import numpy as np
import pandas as pd

# %%
prediction_horizon = 2 # two steps => 30 min
look_back_window = 10 # 10 steps => 2:30h

all_data = Dataset_CPP(config.DATA_PATH, 
                       data_path='private/cpp/20240820pkls/min15.pkl', 
                       features='activity',
                       size=[look_back_window, 0, prediction_horizon], 
                       scale=False, 
                       use_time_features=True,
                       split='all') # no train,  val, test splits
# Out:
# num of subjects in train, val, test 65 10 19
# 1326 timesteps lost as fraction 0.003732046912336301

# %%
generator = io.yield_subject_arrays(all_data)
hours, hours_y, weekdays, days, days_y, x, y = next(generator)

# %% [markdown]
# ### Apply linear baseline for one patient

# %%
# Usage
n = 1000  # validation split
batch_size = 32

x_train = torch.from_numpy(x[:n]).float() 
y_train = torch.from_numpy(y[:n]).float()
x_val = torch.from_numpy(x[-n:]).float()
y_val = torch.from_numpy(y[-n:]).float()

train_loader = DataLoader(TensorDataset(x_train, y_train), batch_size=batch_size, shuffle=True)
val_loader = DataLoader(TensorDataset(x_val, y_val), batch_size=len(x_val), shuffle=False)

# Model, loss function, and optimizer setup
model = pytorch_models.LinearBaseline()
loss_fn = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

trainer = ModelTrainer(model, loss_fn, optimizer, epochs=100)
trainer.train(train_loader, val_loader)

res, ax = trainer.plot_results()
plt.show()

predictions = trainer.predict(val_loader)
# Out:
# Epoch [1/100], Training Loss: 0.93349, Validation Loss: 1.06899
# Epoch [2/100], Training Loss: 0.20318, Validation Loss: 0.55349
# Epoch [3/100], Training Loss: 0.15632, Validation Loss: 0.33067
# Epoch [4/100], Training Loss: 0.01409, Validation Loss: 0.25194
# Epoch [5/100], Training Loss: 0.10247, Validation Loss: 0.22671
# Epoch [6/100], Training Loss: 0.46716, Validation Loss: 0.21987
# Epoch [7/100], Training Loss: 0.13610, Validation Loss: 0.21681
# Epoch [8/100], Training Loss: 0.12348, Validation Loss: 0.21516
# Epoch [9/100], Training Loss: 0.04889, Validation Loss: 0.21446
# Epoch [10/100], Training Loss: 0.05265, Validation Loss: 0.21300
# Epoch [11/100], Training Loss: 0.01629, Validation Loss: 0.21177
# Epoch [12/100], Training Loss: 0.04385, Validation Loss: 0.21018
# Epoch [13/100], Training Loss: 0.16950, Validation Loss: 0.20992
# Epoch [14/100], Training Loss: 0.21154, Validation Loss: 0.20805
# Epoch [15/100], Training Loss: 0.08213, Validation Loss: 0.20672
# Epoch [16/100], Training Loss: 0.03193, Validation Loss: 0.20542
# Epoch [17/100], Training Loss: 0.07907, Validation Loss: 0.20444
# Epoch [18/100], Training Loss: 0.64038, Validation Loss: 0.20303
# Epoch [19/100], Training Loss: 0.08803, Validation Loss: 0.20142
# Epoch [20/100], Training Loss: 0.21184, Validation Loss: 0.20093
# Epoch [21/100], Training Loss: 0.85510, Validation Loss: 0.19972
# Epoch [22/100], Training Loss: 0.06126, Validation Loss: 0.19835
# Epoch [23/100], Training Loss: 0.05826, Validation Loss: 0.19791
# Epoch [24/100], Training Loss: 0.39839, Validation Loss: 0.19632
# Epoch [25/100], Training Loss: 0.22431, Validation Loss: 0.19501
# Epoch [26/100], Training Loss: 0.08074, Validation Loss: 0.19390
# Epoch [27/100], Training Loss: 0.03807, Validation Loss: 0.19327
# Epoch [28/100], Training Loss: 0.30958, Validation Loss: 0.19232
# Epoch [29/100], Training Loss: 0.04268, Validation Loss: 0.19166
# Epoch [30/100], Training Loss: 0.09067, Validation Loss: 0.19001
# Epoch [31/100], Training Loss: 0.07414, Validation Loss: 0.18919
# Epoch [32/100], Training Loss: 0.09635, Validation Loss: 0.18897
# Epoch [33/100], Training Loss: 0.33173, Validation Loss: 0.18748
# Epoch [34/100], Training Loss: 0.06746, Validation Loss: 0.18704
# Epoch [35/100], Training Loss: 0.15633, Validation Loss: 0.18566
# Epoch [36/100], Training Loss: 0.16201, Validation Loss: 0.18549
# Epoch [37/100], Training Loss: 0.28934, Validation Loss: 0.18437
# Epoch [38/100], Training Loss: 0.07581, Validation Loss: 0.18348
# Epoch [39/100], Training Loss: 0.03246, Validation Loss: 0.18262
# Epoch [40/100], Training Loss: 0.01805, Validation Loss: 0.18192
# Epoch [41/100], Training Loss: 0.31749, Validation Loss: 0.18125
# Epoch [42/100], Training Loss: 0.15027, Validation Loss: 0.18061
# Epoch [43/100], Training Loss: 0.13987, Validation Loss: 0.18167
# Epoch [44/100], Training Loss: 0.04642, Validation Loss: 0.18009
# Epoch [45/100], Training Loss: 0.09545, Validation Loss: 0.18015
# Epoch [46/100], Training Loss: 0.55329, Validation Loss: 0.17880
# Epoch [47/100], Training Loss: 0.03772, Validation Loss: 0.17793
# Epoch [48/100], Training Loss: 0.04674, Validation Loss: 0.17698
# Epoch [49/100], Training Loss: 0.41232, Validation Loss: 0.17708
# Epoch [50/100], Training Loss: 0.64901, Validation Loss: 0.17671
# Epoch [51/100], Training Loss: 0.15894, Validation Loss: 0.17589
# Epoch [52/100], Training Loss: 0.11318, Validation Loss: 0.17604
# Epoch [53/100], Training Loss: 0.03651, Validation Loss: 0.17512
# Epoch [54/100], Training Loss: 0.02196, Validation Loss: 0.17507
# Epoch [55/100], Training Loss: 0.04080, Validation Loss: 0.17516
# Epoch [56/100], Training Loss: 0.03506, Validation Loss: 0.17432
# Epoch [57/100], Training Loss: 0.02864, Validation Loss: 0.17404
# Epoch [58/100], Training Loss: 0.06663, Validation Loss: 0.17355
# Epoch [59/100], Training Loss: 0.02256, Validation Loss: 0.17235
# Epoch [60/100], Training Loss: 0.05350, Validation Loss: 0.17360
# Epoch [61/100], Training Loss: 0.01016, Validation Loss: 0.17297
# Epoch [62/100], Training Loss: 0.06281, Validation Loss: 0.17145
# Epoch [63/100], Training Loss: 0.03295, Validation Loss: 0.17239
# Epoch [64/100], Training Loss: 0.47832, Validation Loss: 0.17202
# Epoch [65/100], Training Loss: 0.81612, Validation Loss: 0.17205
# Epoch [66/100], Training Loss: 0.04730, Validation Loss: 0.17304
# Epoch [67/100], Training Loss: 0.07969, Validation Loss: 0.17179
# Epoch [68/100], Training Loss: 0.02928, Validation Loss: 0.17091
# Epoch [69/100], Training Loss: 0.07340, Validation Loss: 0.17046
# Epoch [70/100], Training Loss: 0.07351, Validation Loss: 0.16968
# Epoch [71/100], Training Loss: 0.04821, Validation Loss: 0.17067
# Epoch [72/100], Training Loss: 0.20787, Validation Loss: 0.17035
# Epoch [73/100], Training Loss: 0.02877, Validation Loss: 0.17112
# Epoch [74/100], Training Loss: 0.18146, Validation Loss: 0.17003
# Epoch [75/100], Training Loss: 0.32755, Validation Loss: 0.16988
# Epoch [76/100], Training Loss: 0.28408, Validation Loss: 0.16956
# Epoch [77/100], Training Loss: 0.10642, Validation Loss: 0.16981
# Epoch [78/100], Training Loss: 0.11161, Validation Loss: 0.16997
# Epoch [79/100], Training Loss: 0.35003, Validation Loss: 0.17160
# Epoch [80/100], Training Loss: 0.04797, Validation Loss: 0.17035
# Epoch [81/100], Training Loss: 0.07123, Validation Loss: 0.16956
# Epoch [82/100], Training Loss: 0.06699, Validation Loss: 0.16861
# Epoch [83/100], Training Loss: 0.05202, Validation Loss: 0.16838
# Epoch [84/100], Training Loss: 0.09889, Validation Loss: 0.16952
# Epoch [85/100], Training Loss: 0.04071, Validation Loss: 0.16902
# Epoch [86/100], Training Loss: 0.01767, Validation Loss: 0.16761
# Epoch [87/100], Training Loss: 0.63381, Validation Loss: 0.17051
# Epoch [88/100], Training Loss: 0.00797, Validation Loss: 0.16942
# Epoch [89/100], Training Loss: 0.03563, Validation Loss: 0.16961
# Epoch [90/100], Training Loss: 0.01072, Validation Loss: 0.16891
# Epoch [91/100], Training Loss: 0.27329, Validation Loss: 0.16922
# Epoch [92/100], Training Loss: 0.13891, Validation Loss: 0.16961
# Epoch [93/100], Training Loss: 0.12045, Validation Loss: 0.16884
# Epoch [94/100], Training Loss: 0.29767, Validation Loss: 0.16917
# Epoch [95/100], Training Loss: 0.11298, Validation Loss: 0.16949
# Epoch [96/100], Training Loss: 0.01744, Validation Loss: 0.16876
# Epoch [97/100], Training Loss: 0.97093, Validation Loss: 0.16874
# Epoch [98/100], Training Loss: 0.03656, Validation Loss: 0.16930
# Epoch [99/100], Training Loss: 0.01379, Validation Loss: 0.17083
# Epoch [100/100], Training Loss: 0.05323, Validation Loss: 0.17215

# %%
# Assuming val_output is available from your validation step
f, axs = plt.subplots(5, 10, figsize=[20, 10], sharex=False, sharey=True)
_ = [pics.plot_segment(ax, t, hours_y[n:], y_val.numpy(), predictions, hours[n:], x=x_val.numpy()) for (t, ax) in enumerate(axs.reshape(-1))]

# %%
f,axs=plt.subplots(5,3, figsize=[15,10], sharex=False, sharey=True, tight_layout=True)
hours_y_val, days_y_val = hours_y[-n:], days_y[-n:]
_ = [pics.plot_segment(ax, day, hours_y_val , days_y_val, y_val.numpy(), predictions) 
     for (day,ax) in zip(np.unique(days_y_val), axs.reshape(-1))]

# %%
import importlib # for dev
importlib.reload(pics)
# Out:
# <module 'helpers.plot_helpers' from '/hpc/users/jegmij01/jannes_setup/cpp_project/helpers/plot_helpers.py'>

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

labels = []
for t in range(6,11):
    pics.plot_auc_for_val(tmin=t, tmax=t+2, ax1=ax1, ax2=ax2, predictions=predictions, y_val=y_val.numpy(), hours_y_val=hours_y_val)
    labels.append(f'{t}-{t+2}h')
ax1.legend(labels)
